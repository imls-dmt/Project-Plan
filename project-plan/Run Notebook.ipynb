# %%
# %%bash
# pwd
# ls
# Out:
# /home/jovyan/repos/2018-IMLS-Project/project-plan
# accounts.tji
# holidays.tji
# imls-master.tjp
# macros.tji
# reports
# reports.tji
# resources.tji
# Run Notebook.ipynb
# tasks_admin.tji
# tasks_assessment.tji
# tasks_collection.tji
# tasks_meetings.tji
# tasks_metadata.tji
# tasks_milestones.tji
# tasks_outreach.tji
# tasks.tji
# tasks_usability.tji
# tasks_web.tji

# %%
# %%bash
# tj3 imls-master.tjp
# Out:
# TaskJuggler v3.6.0 - A Project Management Software
#
# Copyright (c) 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016
#               by Chris Schlaeger <cs@taskjuggler.org>
#
# This program is free software; you can redistribute it and/or modify it under
# the terms of version 2 of the GNU General Public License as published by the
# Free Software Foundation.
#
# Reading file imls-master.tjp                                 [      Done      ]
# Preparing scenario Plan Scenario                             [      Done      ]
# Scheduling scenario Plan Scenario                            [      Done      ]
# Checking scenario Plan Scenario                              [      Done      ]
# Report reports/tasksCalendar                                 [      Done      ]
# Report reports/index                                         [      Done      ]
# Report reports/ResourceSummaryReport                         [      Done      ]
# ...
